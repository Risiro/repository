# %%
import numpy as np
import matplotlib.pyplot as plt

# %precision 3
# %matplotlib inline

# %%
x_set = np.array([1, 2, 3, 4, 5, 6])

# %%
def f(x):
    if x in x_set:
        return x / 21
    else:
        return 0

# %%
X = [x_set, f]

# %%
# 확률 p_k를 구한다
prob = np.array([f(x_k) for x_k in x_set])

# x_k 와 p_k 의 대응을 사전식으로 표시한다
dict(zip(x_set, prob))
# Out:
# {np.int64(1): 0.048,
#  np.int64(2): 0.095,
#  np.int64(3): 0.143,
#  np.int64(4): 0.190,
#  np.int64(5): 0.238,
#  np.int64(6): 0.286}

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.bar(x_set, prob)
ax.set_xlabel('value')
ax.set_ylabel('probability')

plt.show()

# %%
a = {'사과':1, '딸기':5, '귤':10}

# %%
a
# Out:
# {'사과': 1, '딸기': 5, '귤': 10}

# %%
a = {('초콜릿', 200):20, ('마카롱', 500):15, ('쿠키', 300):30}
a
# Out:
# {('초콜릿', 200): 20, ('마카롱', 500): 15, ('쿠키', 300): 30}

# %%
a = {'사과':1, '딸기':5, '귤':10}
v1 = a['딸기']
v1
# Out:
# 5

# %%
v2 = a{'레몬']
v2
# Out:
#   Cell In[11], line 1
#     v2 = a{'레몬']
#                ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '{'

# %%
f1 = '딸기' in a
f1
# Out:
# True

# %%
f2 = '레몬' not in a
f2
# Out:
# True

# %%
f2 = '레몬' in a
f2
# Out:
# False

# %%
v1 = a.get('딸기')
v1
# Out:
# 5

# %%
v2 = a.get('레몬')
v2

# %%
a = {'초콜릿':1, '마카롱':2, '쿠키':3}
a['초콜릿'] = 'One'
a['마카롱'] = 'Two'
a['쿠키'] = 'Three'
a
# Out:
# {'초콜릿': 'One', '마카롱': 'Two', '쿠키': 'Three'}

# %%
d = dict(초콜릿 = 20,  마카롱 = 15, 쿠키 = 30)
d
# Out:
# {'초콜릿': 20, '마카롱': 15, '쿠키': 30}

# %%
key = ['초콜릿', '마카롱', '쿠키']
value = [20, 15, 30]
d = dict(zip(key, value))
d
# Out:
# {'초콜릿': 20, '마카롱': 15, '쿠키': 30}

# %%
d = dict([('초콜릿', 20), ('마카롱', 15), ('쿠키', 30)])
d
# Out:
# {'초콜릿': 20, '마카롱': 15, '쿠키': 30}

# %%
np.all(prob >= 0)
# Out:
# np.True_

# %%
np.sum(prob)
# Out:
# 1.000

# %%
def F(x):
    return np.sum([f(x_k) for x_k in x_set if x_k <= x])

# %%
F(3)
# Out:
# 0.286

# %%
y_set = np.array([2 * x_k + 3 for x_k in x_set])
prob = np.array([f(x_k) for x_k in x_set])
dict(zip(y_set, prob))
# Out:
# {np.int64(5): 0.048,
#  np.int64(7): 0.095,
#  np.int64(9): 0.143,
#  np.int64(11): 0.190,
#  np.int64(13): 0.238,
#  np.int64(15): 0.286}

# %%
np.sum([x_k * f(x_k) for x_k in x_set])
# Out:
# 4.333

# %%
np.random.choice(5, 5, replace=False) # shuffle 명령과 같다
# Out:
# array([1, 2, 3, 4, 0], dtype=int32)

# %%
np.random.choice(5, 3, replace=False) # 3개만 선택한다
# Out:
# array([1, 0, 4], dtype=int32)

# %%
np.random.choice(5, 10) # 반복해서 10개를 선택한다
# Out:
# array([1, 4, 0, 0, 0, 0, 4, 2, 3, 3], dtype=int32)

# %%
np.random.choice(5, 10, p=[0.1, 0, 0.3, 0.6, 0]) # 선택 확률을 다르게 해서 10개를 선택한다
# Out:
# array([3, 3, 3, 3, 3, 0, 2, 3, 3, 3], dtype=int32)

# %%
sample = np.random.choice(x_set, int(1e6), p=prob)
np.mean(sample)
# Out:
# 4.333

# %%
def E(X, g=lambda x: x):
    x_set, f = X
    return np.sum([g(x_k) * f(x_k) for x_k in x_set])

# %%
E(X)
# Out:
# 4.333

# %%
E(X, g=lambda x: 2*x + 3)
# Out:
# 11.667

# %%
2 * E(X) + 3
# Out:
# 11.667

# %%
strings = ['hyeja', 'parkhyeja', 'youngtae', 'kimyoungtae', 'bbangtae']

# %%
strings.sort(key=lambda x: len(set(list(x))))

# %%
strings
# Out:
# ['hyeja', 'bbangtae', 'parkhyeja', 'youngtae', 'kimyoungtae']

# %%
2 * E(X) + 3
# Out:
# 11.667

# %%
mean = E(X)
np.sum([(x_k-mean)**2 * f(x_k) for x_k in x_set])
# Out:
# 2.222

# %%
def V(X, g=lambda x: x):
    x_set, f = X
    mean = E(X, g)
    return np.sum([(g(x_k)-mean)**2 * f(x_k) for x_k in x_set])

# %%
V(X)
# Out:
# 2.222

# %%
V(X, lambda x: 2*x + 3)
# Out:
# 8.889

# %%
2**2 * V(X)
# Out:
# 8.889

# %%
x_set = np.arange(2, 13)
y_set = np.arange(1, 7)

# %%
def f_XY(x, y):
    if 1 <= y <= 6 and 1 <= x - y <= 6:
        return y * (x-y) / 441
    else:
        return 0

# %%
XY = [x_set, y_set, f_XY]

# %%
prob = np.array([[f_XY(x_i, y_j) for y_j in y_set]
                 for x_i in x_set])

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

c = ax.pcolor(prob)
ax.set_xticks(np.arange(prob.shape[1]) + 0.5, minor = False)
ax.set_yticks(np.arange(prob.shape[0]) + 0.5, minor = False)
ax.set_xticklabels(np.arange(1, 7), minor = False)
ax.set_yticklabels(np.arange(2, 13), minor = False)

# y축을 내림차순의 숫자로 하여, 위 아래 역전
ax.invert_yaxis()

# x축의 눈금을 그래프 위쪽에 표시
ax.xaxis.tick_top

fig.colorbar(c, ax=ax)
plt.show()

# %%
np.all(prob >= 0)
# Out:
# np.True_

# %%
np.sum(prob)
# Out:
# 1.000

# %%
def f_X(x):
    return np.sum([f_XY(x, y_k) for y_k in y_set])

# %%
def f_Y(y):
    return np.sum([f_XY(x_k, y) for x_k in x_set])

# %%
X = [x_set, f_X]
Y = [y_set, f_Y]

# %%
prob_x = np.array([f_X(x_k) for x_k in x_set])
prob_y = np.array([f_Y(y_k) for y_k in y_set])

fig = plt.figure(figsize=(12, 4))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax1.bar(x_set, prob_x)
ax1.set_title('X_marginal probability sistribution')
ax1.set_xlabel('X_value')
ax1.set_ylabel('probability')
ax1.set_xticks(x_set)

ax2.bar(y_set, prob_y)
ax2.set_title('Y_marginal probability sistribution')
ax2.set_xlabel('Y_value')
ax2.set_ylabel('probability')

plt.show()

# %%
np.sum([x_i * f_XY(x_i, y_j) for x_i in x_set for y_j in y_set])
# Out:
# 8.667

# %%
def E(XY, g):
    x_set, y_set, f_XY = XY
    return np.sum([g(x_i, y_j) * f_XY(x_i, y_j)
                    for x_i in x_set for y_j in y_set])

# %%
mean_X = E(XY, lambda x, y: x)
mean_X
# Out:
# 8.667

# %%
mean_Y = E(XY, lambda x, y: y)
mean_Y
# Out:
# 4.333

# %%
a, b = 2, 3

# %%
E(XY, lambda x, y: a*x + b*y)
# Out:
# 30.333

# %%
a * mean_X + b * mean_Y
# Out:
# 30.333

# %%
np.sum([(x_i-mean_X)**2 * f_XY(x_i, y_j)
        for x_i in x_set for y_j in y_set])
# Out:
# 4.444

# %%
def V(XY, g):
    x_set, y_set, f_XY = XY
    mean = E(XY, g)
    return np.sum([(g(x_i, y_j)-mean)**2 * f_XY(x_i, y_j)
                    for x_i in x_set for y_j in y_set])

# %%
var_X = V(XY, g=lambda x, y: x)
var_X
# Out:
# 4.444

# %%
var_Y = V(XY, g=lambda x, y: y)
var_Y
# Out:
# 2.222

# %%
def Cov(XY):
    x_set, y_set, f_XY = XY
    mean_X = E(XY, g=lambda x, y: x)
    mean_Y = E(XY, g=lambda x, y: y)
    return np.sum([(x_i-mean_X) * (y_j-mean_Y) * f_XY(x_i, y_j)
                    for x_i in x_set for y_j in y_set])

# %%
cov_xy = Cov(XY)
cov_xy
# Out:
# 2.222

# %%
V(XY, lambda x, y: a*x + b*y)
# Out:
# 64.444

# %%
a**2 * var_X + b**2 * var_Y + 2*a*b * cov_xy
# Out:
# 64.444

# %%
cov_xy /np.sqrt(var_X * var_Y)
# Out:
# 0.707
